# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
import networkx as nx

def xy_plotting(x, y, x_label, y_label, title):
    plt.plot(x, y, label=title, color='blue', marker='o', linestyle='-', linewidth=2)
    plt.ylabel(y_label)
    plt.xlabel(x_label)
    plt.title(title)
    plt.show()

def x_label(x_label, y_label, title):
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    plt.grid()

def graph_draw(adj_matrix, cut):
    assert(adj_matrix.shape[0]==len(cut))
    G = nx.from_numpy_array(adj_matrix)
    node_colors = ['blue' if cut[i] == 1 else 'red' for i in range(len(cut))]
    link = []
    for i in range(0,len(cut)):
        #print("i:",i)
        for j in range(0,len(cut)):
            #print("j:",j)
            if cut[i] != cut[j] and adj_matrix[i,j] !=0:
                link.append((i,j))

    edge_colors = ['blue' if edge in link else 'lightgray' for edge in G.edges()]
    pos = nx.spring_layout(G)
    nx.draw(G, pos, with_labels=True, node_size=300, font_size=12, font_weight='bold',
            edge_color=edge_colors, node_color=node_colors)

    # Optional: Customize the plot appearance
    plt.title('Graph with Custom Node Colors', fontsize=16)
    plt.axis('off')  # Turn off the axis
    plt.show()

# %%
#Algoritmo Nelder-Mead
Cost_iteration_p15_it35 = [np.float64(8.094333333333333), np.float64(8.07753333333333), np.float64(8.078900000000003), np.float64(8.087433333333335), np.float64(8.062433333333326), np.float64(8.073799999999988), np.float64(8.089299999999984), np.float64(8.072933333333324), np.float64(8.078066666666658), np.float64(8.090066666666667), np.float64(8.096033333333343), np.float64(8.081433333333331), np.float64(8.082166666666682), np.float64(8.074066666666653), np.float64(8.067499999999997), np.float64(8.083399999999996), np.float64(8.055966666666674), np.float64(8.083766666666662), np.float64(8.080000000000007), np.float64(8.087566666666671), np.float64(8.084433333333324), np.float64(8.088533333333327), np.float64(8.01136666666665), np.float64(7.99746666666666), np.float64(7.9851333333333265), np.float64(7.988766666666665), np.float64(7.998899999999999), np.float64(8.01589999999999), np.float64(8.002200000000002), np.float64(8.000766666666653), np.float64(7.985066666666663), np.float64(7.992599999999998), np.float64(8.001866666666665), np.float64(7.996066666666662)]
Cost_iteration_p2_it35 = [np.float64(8.111966666666653), np.float64(8.123733333333325), np.float64(8.03456666666666), np.float64(8.05646666666666), np.float64(7.907733333333335), np.float64(7.9116333333333255), np.float64(7.914366666666655), np.float64(7.869666666666668), np.float64(7.840199999999998), np.float64(7.783699999999991), np.float64(7.779333333333334), np.float64(7.681533333333319), np.float64(7.47703333333333), np.float64(7.460000000000002), np.float64(7.0649000000000015), np.float64(7.064133333333336), np.float64(6.616200000000003), np.float64(6.265666666666664), np.float64(5.879866666666673), np.float64(5.667799999999999), np.float64(5.674833333333331), np.float64(5.55803333333334), np.float64(5.553800000000004), np.float64(5.48863333333334), np.float64(5.465300000000014), np.float64(5.0141), np.float64(5.030100000000004), np.float64(4.908999999999995), np.float64(4.183466666666671), np.float64(4.185966666666674), np.float64(4.176833333333339), np.float64(4.16776666666666), np.float64(4.191966666666674), np.float64(4.198466666666676)]
x_label("Iteration", "Hamiltonian", "Hamiltonian vs Iteration")
plt.plot(Cost_iteration_p15_it35, marker='o', linestyle='-', label='p=15')
plt.plot(Cost_iteration_p1_it35, marker='o', linestyle='-', label='p=1')
plt.plot(Cost_iteration_p5_it35, marker='o', linestyle='-', label='p=5')
plt.plot(Cost_iteration_p2_it35, marker='o', linestyle='-', label='p=2')
plt.plot(Cost_iteration_p4_it35, marker='o', linestyle='-', label='p=4')
plt.plot(Cost_iteration_p3_it35, marker='o', linestyle='-', label='p=3')
plt.legend()
plt.show()

# %%
p_points = [1,2,3,4,5]
H_NelderMead = [min(Cost_iteration_p1_it35), min(Cost_iteration_p2_it35), min(Cost_iteration_p3_it35), min(Cost_iteration_p4_it35), min(Cost_iteration_p5_it35)]
xy_plotting(p_points, H_NelderMead, "p", "Hamiltonian", "Hamiltonian vs p - Nelder Mead algorithm")

# %%
'''method:  l-bfgs-b  layer_num:  1 best_hamilton:  7.762566666666679
method:  l-bfgs-b  layer_num:  2 best_hamilton:  7.899300000000007
method:  l-bfgs-b  layer_num:  3 best_hamilton:  7.670033333333332
method:  l-bfgs-b  layer_num:  4 best_hamilton:  8.451900000000009
method:  l-bfgs-b  layer_num:  5 best_hamilton:  6.839066666666654'''

H_l_bfgs_b = [7.762566666666679,7.899300000000007,7.670033333333332,8.451900000000009,6.839066666666654]
xy_plotting(p_points, H_l_bfgs_b, "p", "Hamiltonian", "Hamiltonian vs p - l-bfgs-b algorithm")

# %%
'''method:  cobyla  layer_num:  1 best_hamilton:  4.579700000000005
method:  cobyla  layer_num:  2 best_hamilton:  4.507800000000008
method:  cobyla  layer_num:  3 best_hamilton:  4.628699999999996
method:  cobyla  layer_num:  4 best_hamilton:  4.570000000000003
method:  cobyla  layer_num:  5 best_hamilton:  4.867933333333347'''

H_cobyla = [4.579700000000005,4.507800000000008,4.628699999999996,4.570000000000003,4.867933333333347]
xy_plotting(p_points, H_cobyla, "p", "Hamiltonian", "Hamiltonian vs p - cobyla algorithm")

# %%
'''method:  bfgs  layer_num:  1 best_hamilton:  7.723933333333331
method:  bfgs  layer_num:  2 best_hamilton:  7.547866666666659
method:  bfgs  layer_num:  3 best_hamilton:  8.474533333333337
method:  bfgs  layer_num:  4 best_hamilton:  8.00129999999999
method:  bfgs  layer_num:  5 best_hamilton:  7.643866666666663'''

H_bfgs = [7.723933333333331,7.547866666666659,8.474533333333337,8.00129999999999,7.643866666666663]
xy_plotting(p_points, H_bfgs, "p", "Hamiltonian", "Hamiltonian vs p - bfgs algorithm")

# %%
x_label("Number of layers", "Hamiltonian", "Hamiltonian vs Number of layers for different algorithms")
plt.plot(p_points, H_NelderMead, marker='o', linestyle='-', label='Nelder-Mead', color='red')
plt.plot(p_points, H_l_bfgs_b, marker='o', linestyle='-', label='l-bfgs-b', color='green')
plt.plot(p_points, H_cobyla, marker='o', linestyle='-', label='cobyla', color='blue')
plt.plot(p_points, H_bfgs, marker='o', linestyle='-', label='bfgs', color='black')
plt.legend()
plt.show()

# %%
n_qubit=[3,5,8, 13, 16, 20]
c1=[1,4,9,24,43,66] #local_search_max_cut
c2=[1,4,9,24,42,64] #kernighan_lin_max_cut
s=[1,4,9,23,40,61] #quantum-gate-based-annealing

d_angle=0.05
iteration=100

x_label("Number of qubits", "Number of iterations", "Number of iterations vs Number of qubits")
plt.plot(n_qubit, c1, marker='o', linestyle='-', label='Local search max cut',color='red')
plt.plot(n_qubit, c2, marker='o', linestyle='-', label='Kernighan-Lin max cut',color='blue')
plt.plot(n_qubit, s, marker='o', linestyle='-', label='Quantum gate-based adiabatic',color='green')
plt.legend()
plt.show()

# %%
# Definisci la funzione esponenziale
def exp_func(x, a, b, c):
    return a * np.exp(b * x) + c

popt, pcov = curve_fit(exp_func, n_qubit, c1)
a, b, c = popt

x_fit = np.linspace(min(n_qubit), 1000, 100)
y_fit = exp_func(x_fit, *popt)

x_label("Number of qubits", "Number of iterations", "Number of iterations vs Number of qubits with Exponential Fit")
plt.plot(n_qubit, c1, marker='o', linestyle='-', label='Local search max cut')
plt.plot(x_fit, y_fit, label='Exponential Fit', linestyle='--', color='red')
plt.yscale('log')
plt.legend()
plt.show()

# %%
n_qubit=[3,5,8, 13, 16, 20]
t1=[0.00179290771484375,0.0025243759155273438,0.006896257400512695,0.024335384368896484,0.04770660400390625,0.11614775657653809] #local_search_max_cut
t2=[8.416175842285156e-05,9.489059448242188e-05,0.00022339820861816406,0.0009491443634033203,0.002794027328491211,0.011802911758422852] #kernighan_lin_max_cut
t=[2.433394432067871,11.905713081359863,22.599396228790283,70.42817950248718,137.8834969997406,226.6230664253235] #quantum-gate-based-annealing

d_angle=0.05
iteration=100

x_label("Number of qubits", "Time (s)", "Time vs Number of qubits")
plt.plot(n_qubit, t1, marker='o', linestyle='-', label='Local search max cut')
plt.plot(n_qubit, t2, marker='o', linestyle='-', label='Kernighan-Lin max cut')
plt.plot(n_qubit, t, marker='o', linestyle='-', label='Quantum gate-based adiabatic')
#plt.yscale('log')
plt.legend()

# %%
# Definisci la funzione esponenziale
def exp_func(x, a, b, c):
    return a * np.exp(b * x) + c

popt, pcov = curve_fit(exp_func, n_qubit, t1)
a, b, c = popt


x_fit = np.linspace(min(n_qubit), 170, 100)
y_fit = exp_func(x_fit, *popt)

x_label("Number of qubits", "Time", "Time vs Number of qubits with Exponential Fit")
plt.plot(n_qubit, t1, marker='o', linestyle='-', label='Local search max cut', color='red')
plt.plot(x_fit, y_fit, linestyle='--', color='red')

popt, pcov = curve_fit(exp_func, n_qubit, t2)
a, b, c = popt


x_fit = np.linspace(min(n_qubit), 170, 100)
y_fit = exp_func(x_fit, *popt)
plt.plot(n_qubit, t2, marker='o', linestyle='-', label='Kernighan-Lin max cut', color='blue')
plt.plot(x_fit, y_fit, linestyle='--', color='blue')

popt, pcov = curve_fit(exp_func, n_qubit, t)
a, b, c = popt


x_fit = np.linspace(min(n_qubit), 170, 100)
y_fit = exp_func(x_fit, *popt)
plt.plot(n_qubit, t, marker='o', linestyle='-', label='Quantum gate-based adiabatic', color='green')
plt.plot(x_fit, y_fit, linestyle='--', color='green')

plt.yscale('log')
plt.legend()
plt.show()
